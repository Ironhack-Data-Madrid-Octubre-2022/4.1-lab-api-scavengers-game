# %%
import json
import requests

# %% [markdown]
# Only if you're using your environmental variable eith the `.env` file, import/install the following modules. Otherwise it is not necessary:
#
# https://pypi.org/project/python-dotenv/

# %%
import os
from dotenv import load_dotenv

# %%
# %pip install python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
load_dotenv()
# Out:
# False

# %%
github = os.getenv("token")

# %% [markdown]
# # Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp. Assuming the main lab repo is ironhack-datalabs/datamad1020-rev, you will:
#
# 1. Obtain the full list of forks created from the main lab repo via Github API.
#
# 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
#
# Hint: Each language should appear only once in your array.
#
# 3. Print the language array. It should be something like:
#
# ["Python", "Jupyter Notebook", "HTML"]

# %% [markdown]
# **HINT:**: Create a list with every **language_url** you find in every fork

# %% [markdown]
# ⚠️ **Remember to limit your output before submission**.

# %%
import requests as req

# %%
url="https://api.github.com/repos/ironhack-datalabs/datamad1020-rev"

# %%
with open('../tok.txt', 'r') as file:

     pass_=file.readlines()

token = ''.join(pass_)

# %%
header={'Authorization': 'token '+ token}

res=req.get(url, headers=header)

# %%
res_git=req.get(url)

res_git
# Out:
# <Response [200]>

# %%
res_git.json()
# Out:
# {'id': 304248539,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkzMDQyNDg1Mzk=',
#  'name': 'datamad1020-rev',
#  'full_name': 'ironhack-datalabs/datamad1020-rev',
#  'private': False,
#  'owner': {'login': 'ironhack-datalabs',
#   'id': 44225188,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ironhack-datalabs',
#   'html_url': 'https://github.com/ironhack-datalabs',
#   'followers_url': 'https://api.github.com/users/ironhack-datalabs/followers',
#   'following_url': 'https://api.github.com/users/ironhack-datalabs/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/ironhack-datalabs/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/ironhack-datalabs/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/ironhack-datalabs/subscriptions',
# ...

# %%
res_git.json()['languages_url']
# Out:
# 'https://api.github.com/repos/ironhack-datalabs/datamad1020-rev/languages'

# %%
url2 = res_git.json()['languages_url']

# %%
header={'Authorization': ''}

res2=req.get(url2, headers=header)

# %%
res_git=req.get(url2)

res_git
# Out:
# <Response [200]>

# %%
language=res_git.json()

# %%
keys = []
for key in language:
    keys.append(key)
    
keys
# Out:
# ['Jupyter Notebook', 'HTML', 'Python']

# %%
url3 = 'https://api.github.com/repos/Ironhack-Data-Madrid-Octubre-2022/apuntes_clase/forks'

# %%
header={'Authorization': 'token '+ token}

res3=req.get(url3, headers=header)

# %%
res3=req.get(url2)

res3
# Out:
# <Response [200]>

# %%
posiciones=[]
for i in range(10):
    res3 = req.get(url3, headers=header)
    data = res3.json()
    posiciones.append(data)
posiciones
# Out:
# [[{'id': 558378868,
#    'node_id': 'R_kgDOIUgvdA',
#    'name': 'apuntes_clase',
#    'full_name': 'pablogalann/apuntes_clase',
#    'private': False,
#    'owner': {'login': 'pablogalann',
#     'id': 113049032,
#     'node_id': 'U_kgDOBrz9yA',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/113049032?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/pablogalann',
#     'html_url': 'https://github.com/pablogalann',
#     'followers_url': 'https://api.github.com/users/pablogalann/followers',
#     'following_url': 'https://api.github.com/users/pablogalann/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/pablogalann/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/pablogalann/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/pablogalann/subscriptions',
#     'organizations_url': 'https://api.github.com/users/pablogalann/orgs',
# ...
